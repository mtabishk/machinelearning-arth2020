# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
time = np.arange(0,1500)

# %%
time
# Out:
# array([   0,    1,    2, ..., 1497, 1498, 1499])

# %%
time.shape
# Out:
# (1500,)

# %%
# y = sin(xt) + b
y_with_noise = np.sin(0.02 * time) + np.random.uniform(low=-1, high=1, size=(1500,))

# %%
y = np.sin(0.02 * time)

# %%
y.shape
# Out:
# (1500,)

# %%
plt.plot(y_with_noise)
plt.axvline(1000, c='r')
plt.plot(y)

# %%
##########

# %%
np.linspace(1,20,10)
# Out:
# array([ 1.        ,  3.11111111,  5.22222222,  7.33333333,  9.44444444,
#        11.55555556, 13.66666667, 15.77777778, 17.88888889, 20.        ])

# %%
np.pi

# %%
inp = np.linspace(-np.pi, np.pi, 20)

# %%
inp
# Out:
# array([-3.14159265, -2.81089869, -2.48020473, -2.14951076, -1.8188168 ,
#        -1.48812284, -1.15742887, -0.82673491, -0.49604095, -0.16534698,
#         0.16534698,  0.49604095,  0.82673491,  1.15742887,  1.48812284,
#         1.8188168 ,  2.14951076,  2.48020473,  2.81089869,  3.14159265])

# %%
opt = np.sin(inp)

# %%
opt
# Out:
# array([-1.22464680e-16, -3.24699469e-01, -6.14212713e-01, -8.37166478e-01,
#        -9.69400266e-01, -9.96584493e-01, -9.15773327e-01, -7.35723911e-01,
#        -4.75947393e-01, -1.64594590e-01,  1.64594590e-01,  4.75947393e-01,
#         7.35723911e-01,  9.15773327e-01,  9.96584493e-01,  9.69400266e-01,
#         8.37166478e-01,  6.14212713e-01,  3.24699469e-01,  1.22464680e-16])

# %%
plt.plot(inp, opt, marker='o')
